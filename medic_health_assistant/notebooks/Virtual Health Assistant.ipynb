# %%
import os
import json
import os
import numpy as np
import nltk
from nltk import LancasterStemmer, WordNetLemmatizer
import random
import pickle
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import SGD

# %%
stemmer = LancasterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
path = "../dataset/medical-question-answer-data"

# %%
def load_doc(jsonFile):
    with open(jsonFile) as file:
        Json_data = json.loads(file.read())
    return Json_data

# %%
# Load the files
file1 = load_doc(os.path.abspath(os.path.join(path, "ehealthforumQAs.json")))
file2 = load_doc(os.path.abspath(os.path.join(path, "healthtapQAs.json")))
file3 = load_doc(os.path.abspath(os.path.join(path, "icliniqQAs.json")))
file4 = load_doc(os.path.abspath(os.path.join(path, "questionDoctorQAs.json")))
file5 = load_doc(os.path.abspath(os.path.join(path, "webmdQAs.json")))
file6 = load_doc(os.path.abspath(os.path.join(path, "medical_intent.json")))

# %%
# Select the files to be used for training and concatenate them
all_Files = [file1, file3, file4, file6]

# %%
words = []
labels = []
documents = []
ignore_words = ['?', '!']

# %%
for data in all_Files:
    for intent in data:
        if len(intent['tags']) == 0:
            tag = "unspecified"
        else:     
            ##Extracting only the first tags as they're the most relevant
            tag = intent['tags'][0]
            question = intent["question"]
            wrds = nltk.word_tokenize(question)
    
            words.extend(wrds)
            documents.append((wrds, tag))
            
            if tag not in labels:
                labels.append(tag)

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

labels = sorted(list(set(labels)))

print (len(documents), "documents")

print (len(labels), "labels", labels)

print (len(words), "unique lemmatized words", words)
pickle.dump(words, open('words.pkl','wb'))
pickle.dump(labels, open('labels.pkl','wb'))
# Out:
# 5942 documents
# 1891 labels ['"cannabis episode" that really scared me', '(heterozygous) factor v liden', '(temporomandibular joint disorders) tmj', '100% deaf in my right ear hypothyroidism pain in hands and feet', '103 fever', '13cm 9 cm', '2 endometrial biopsy-both came negative', '20 months old boy does not communicate', '2nd opinion', '35 weeks pregnant', '4 back surgeries', '5 week old baby had bronchiolitis and therapy', '5mm solid nodule in throat', '5mm stone in left kidney (oxalate stones)', '5th spinal fusion pain right now', '6 weeks of physical therapy and then got a epidural steroid injection', '6 year old was diagnosed with cellulitis', '65 year old male with cervical spine (neck) pain', "82 year old male fully conscious but can't stand up", 'a lot of bleeding every day', 'a week ago i had a medical abortion', 'abdomen', 'abdomen numbness', 'abdominal pain', 'abdominal pain and constipation and rectal bleeding has been more frequent', 'abdominal pain and the blood test results for my liver', 'abdominal pain that feels like pancreatitis', 'abnormal blood results', 'abnormal blood test results', 'abnormal ecg', 'abortion', 'abortion cause', 'abortion debate', 'abortion tablets', 'abortions', 'abscess between my legs', 'abused as a child', 'accident right hip', 'accompanied by constipation', 'aches', 'achilles stiffness', 'aching pain i have had in my left leg', 'acid reflex', 'acid reflux', 'acinetobacter anitratus', 'acne', 'acne scars', 'acoustic neuroma surgery seconadary effects', 'acoustic nouroma tumour', 'across my stomach', 'act', 'active thyroid', 'acupuncture physio and doctors may have caused permanent damage', 'acute ebv antibody test', 'acute lymphocytes leukemia', 'acute pancreatitis', 'add', 'add/adhd', 'adderall is causing some problems', 'adderall use for studying', 'addiction', 'addiction, recovery', "addison's disease", 'adhd attention deficit disorder', 'admitted to hospital', 'admitted to hospital with recurring stomach pains', 'adolescent medicine pediatrics', 'adrenaline crisis', 'adult acne', 'adult polycyclic kidney disease', 'advanced intracranial atrophy', 'advice regarding thalassemia and pregnancy', 'afford', 'after a bowel movement abdominal pain', 'after giving birth i continue to vomit', 'ain in chest with palpable lump', 'albinos', 'alkph=769', 'allergies and colon issues', 'allergies or skin conditions', 'allergy', 'allergy & immunology', 'allergy to cosmetics', 'alternative', 'always tired', "alzheimer's", 'am i diabetic?', 'am i pregnant', 'am i taking the wrong meds', 'ami', 'amoebiasis', 'amoxicillin', 'an std or throat cancer', 'ana test', 'anabolic steroids secondary effects', 'and a high heart rate?', 'and diabetes', 'and mmr vaccines now can barely move', 'and my hot and cold flushes were more extreme.', 'and naproxen', 'and physical therapist', 'and rubella vaccine', 'anemia', 'aneurysm in the family', 'angioedema swelling remedy', 'angiography', 'angiography? or bypass surgery', 'ankle is now huge and swollen', 'ankle swelling', 'anterior shoulder dislocations', 'anterior wall interstitial uterine fibroid', 'anterlothesis of l4 on l5 do i need surgery', 'anti depressant (escitalopram)', 'anti-coagulants and the elderly', 'antibiotics', 'antibiotics and steroids for cough', 'antibiotics not working', 'antidepressant', 'antidepressants destroyed my libido', 'anxiety', 'anxiety and stress', 'anxiety problems', 'aortic valve and pulmonary valve malfunction', 'aortic valve replaced with a mechanical one', 'appendix and appendicitis', 'apple cider vinegar to relieve cold and flu', 'are my semen analysis results good', 'are these spots next to my labia normal?', 'aripiprazole 5ml and sertraline 50ml', 'armpits', 'arms and legs numb', 'arms have fallen asleep', 'arogyam package test result shows imbalance in homocystein level', 'arrhythmias', 'arthritis', 'arthrosis of the hip joint (coxarthrosis)', 'asthma allergies', 'asthma and chronic bronchitis', "athlete's foot on the hands", 'ativan', 'a ...
# 5237 unique lemmatized words ['%', '&', "'", "''", "'d", "'ll", "'m", "'re", "'s", "'ve", '(', ')', '*******', '+', ',', '-', '--', '-10th', '-146', '-39', '-90', '-and', '-everyone', '-lou', '-no', '-should', '-very', '.', '/', '/liquid', '/slightly', '0', '03', '04', '07', '1', '1-10', '1-2', '1-5', '1.', '1/2', '1/2016', '10', '10/11/2016', '100', '101', '102', '103', '107', '10cm', '10mg', '10yr', '11', '110', '115', '11th', '12', '12.', '12/03/2012', '12000', '123/min', '128', '12th', '13', '13.', '131', '13cm', '14', '1400', '140lbs', '15', '150', '15mg', '15th', '15yrs', '16', '16.', '165', '17', '17000', '175', '18', '18.', '180', '1800', '18th', '18yrs', '19', '19.', '1992', '19weeks', '1:41', '1gg3', '1st', '2', '2+', '2-', '2-3', '2-3x', '2-week', '2.', '20', '20-30', '200', '2008', '2009', '2010', '2011', '2012', '2012.', '2013', '2014', '2014.', '2015', '2015.', '2016', '2017', '205', '20mg', '20mgs', '20min', '20yrs', '21', '22', '23', '24', '24/7', '240/110', '249lbs', '25', '250mcg', '25mg', '26', '27', '27/nl', '28', '29', '29-30', '2and', '2diabet', '2g', '2nd', '2year', '3', '3-4', '3.', '30', '300', '300calorie', '30ml', '31', '32', '33', '33+4', '34ff', '35', '36', '36c', '37', '37and', '38', '39', '3b', '3d', '3rd', '3st', '4', '4-5', '40', '40-year-old', '40000', '40k', '40mg', '41', '41-', '42', '42y/o', '43', '44', '44.', '45', '450g', '46', '4b2', '4cm', '4months', '4pm', '4th', '5', '50', '50-50', '500', '500mg', '50ml', '52', '520', '53', '54', '54.', '55', '550', '58', '58-year-old', '5\\', '5cm', '5ft', '5in', '5k', '5mg', '5ml', '5mm', '5th', '6', '6-7', '6.', '60', '60lbs', '61', '62', '63', '65', '65yrs', '69', '6mo', '6th', '7', '7-8', '7/nl', '71', '72', '73', '74', '77', '78kgs', '8', '8-100', '8-9', '8-month-old', '8.', '80', '82', '85-90', '85/55', '87', '8th', '9', '90/60', '91', '975', '98', '9kg', '9th', ':', ';', '<', '>', '@', '\\', '``', 'a', 'a.', 'a1c', 'aarskog-scott', 'ab', 'ab/ag', 'abdomen', 'abdomen/discomfort', 'abdominal', 'ability', 'ablation', 'able', 'abnormal', 'abnormality', 'abnormally', 'abort', 'abortion', 'about', 'above', 'abrupt', 'abruptly', 'abscess', 'absence', 'absolutely', 'abused', 'abusing', 'abusive', 'accelerator', 'accept', 'accepted', 'accident', 'accident…', 'accompanied', 'according', 'accurate', 'accutane', 'achalasia', 'ache', 'ache/pain', 'achieve', 'achilles…can', 'aching', 'achy', 'achy-', 'acid', 'acidity', 'acinetobacter', 'acl', 'acne', 'aconitum', 'acoustic', 'acquired', 'across', 'act', 'acting', 'action', 'active', 'activity', 'activity…but', 'actual', 'actually', 'acupuncture', 'acute', 'adam', 'adamond', 'add', 'add/adhd', 'added', 'adderall', 'addicted', 'adding', 'addison', 'additional', 'addressed', 'adenocarcinoma', 'adenoma', 'adenomyosis', 'adhd', 'adhd/add', 'adhesion', 'adjustment', 'administer', 'admission', 'admitted', 'adolescence', 'adrenal', 'adrenaline', 'adult', 'advance', 'advanced', 'advantage', 'adversarial', 'adverse', 'advice', 'advisable', 'advise', 'advised', 'advse', 'afect', 'affair', 'affect', 'affected', 'afford', 'afghanistan', 'afib', 'afp', 'afraid', 'africa', 'afriend', 'after', 'afternoon', 'afterwards', 'ag/ab', 'again', 'age', 'agen', 'aggressive', 'ago', 'agony', 'ago…my', 'ago…pain', 'agree', 'agressive', 'aicardi–goutières', 'aid', 'airway', 'al', 'alarming', 'albicans', 'albino', 'alcohol', 'all', 'all.', 'allergic', 'allergy', 'allow', 'almond', 'almost', 'almostall', 'alone', 'along', 'alot', 'aloud', 'alpha-fetoprotein', 'alphabet', 'already', 'also', 'alsp', 'alta', 'altered', 'alternate', 'alternating', 'alternative', 'although', 'always', 'alzheimers', 'am', 'amebiasis', 'amenorrhea', 'amnesia', 'amniocentesis', 'amoebiasis', 'amount', 'amoxicillin', 'amphetamine', 'amputate', 'amputated', 'amylase', 'amyotrophic', 'an', 'ana', 'anabolic', 'anaemia', 'anaemic', 'anal', 'analysis', 'anatomy', 'anchor', 'and', 'and/or', 'andersson', 'anemia', 'anemic', 'anesthetic', 'aneurysm', 'anger', 'angina', ' ...

# %%
training = []
out_empty = [0 for _ in range(len(labels))]

# %%
for doc in documents:
    bag = []
    
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]

    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
        

    output_row = out_empty[:]
    output_row[labels.index(doc[1])] = 1

    training.append([bag, output_row])

# %%
random.shuffle(training)
training = np.array(training)

# %%
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created

# %%
model = Sequential()
model.add(Dense(64, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(len(train_y[0]), activation='softmax'))

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=['accuracy'])
model.summary()

hist = model.fit(np.array(train_x), np.array(train_y), epochs=100, batch_size=5, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                335232
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1891)              122915
# =================================================================
# Total params: 474,723
# Trainable params: 474,723
# Non-trainable params: 0
# _________________________________________________________________
# Train on 5942 samples
# Epoch 1/100
# 5942/5942 [==============================] - 7s 1ms/sample - loss: 7.3982 - accuracy: 0.0044
# Epoch 2/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 5.6007 - accuracy: 0.1117
# Epoch 3/100
# 5942/5942 [==============================] - 7s 1ms/sample - loss: 3.8086 - accuracy: 0.3240
# Epoch 4/100
# 5942/5942 [==============================] - 7s 1ms/sample - loss: 2.7499 - accuracy: 0.4699
# Epoch 5/100
# 5942/5942 [==============================] - 7s 1ms/sample - loss: 2.0930 - accuracy: 0.5890
# Epoch 6/100
# 5942/5942 [==============================] - 7s 1ms/sample - loss: 1.7000 - accuracy: 0.6515
# Epoch 7/100
# 5942/5942 [==============================] - 7s 1ms/sample - loss: 1.4261 - accuracy: 0.7006
# Epoch 8/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 1.2219 - accuracy: 0.7415
# Epoch 9/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 1.0485 - accuracy: 0.7703
# Epoch 10/100
# 5942/5942 [==============================] - 7s 1ms/sample - loss: 0.9533 - accuracy: 0.7869
# Epoch 11/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.8595 - accuracy: 0.8043
# Epoch 12/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.7798 - accuracy: 0.8181
# Epoch 13/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.7254 - accuracy: 0.8287
# Epoch 14/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.6331 - accuracy: 0.8509
# Epoch 15/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.6072 - accuracy: 0.8516
# Epoch 16/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.5662 - accuracy: 0.8696
# Epoch 17/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.5403 - accuracy: 0.8657
# Epoch 18/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.5092 - accuracy: 0.8777
# Epoch 19/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.4370 - accuracy: 0.8898
# Epoch 20/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.4624 - accuracy: 0.8886
# Epoch 21/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.4224 - accuracy: 0.8948
# Epoch 22/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.4339 - accuracy: 0.8911
# Epoch 23/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.3905 - accuracy: 0.9049
# Epoch 24/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.3793 - accuracy: 0.9029
# Epoch 25/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.3759 - accuracy: 0.9056
# Epoch 26/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.3616 - accuracy: 0.9103
# Epoch 27/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.3347 - accuracy: 0.9165
# Epoch 28/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.3544 - accuracy: 0.9098
# Epoch 29/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.3473 - accuracy: 0.9135
# Epoch 30/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.3365 - accuracy: 0.9155
# Epoch 31/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.3083 - accuracy: 0.9233
# Epoch 32/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.3160 - accuracy: 0.9162
# Epoch 33/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2972 - accuracy: 0.9233
# Epoch 34/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.3225 - accuracy: 0.9207
# Epoch 35/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.3133 - accuracy: 0.9216
# Epoch 36/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2983 - accuracy: 0.9234
# Epoch 37/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.3131 - accuracy: 0.9263
# Epoch 38/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2676 - accuracy: 0.9329
# Epoch 39/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2821 - accuracy: 0.9313
# Epoch 40/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2536 - accuracy: 0.9355
# Epoch 41/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2696 - accuracy: 0.9327
# Epoch 42/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2581 - accuracy: 0.9349
# Epoch 43/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2643 - accuracy: 0.9337
# Epoch 44/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2714 - accuracy: 0.9352
# Epoch 45/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2594 - accuracy: 0.9344
# Epoch 46/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2597 - accuracy: 0.9403
# Epoch 47/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2739 - accuracy: 0.9312
# Epoch 48/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2801 - accuracy: 0.9330
# Epoch 49/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2458 - accuracy: 0.9408
# Epoch 50/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2590 - accuracy: 0.9360
# Epoch 51/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2502 - accuracy: 0.9389
# Epoch 52/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2713 - accuracy: 0.9372
# Epoch 53/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2615 - accuracy: 0.9374
# Epoch 54/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2261 - accuracy: 0.9431
# Epoch 55/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2261 - accuracy: 0.9468
# Epoch 56/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2483 - accuracy: 0.9428
# Epoch 57/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2342 - accuracy: 0.9453
# Epoch 58/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2669 - accuracy: 0.9367
# Epoch 59/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2569 - accuracy: 0.9389
# Epoch 60/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2378 - accuracy: 0.9429
# Epoch 61/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2177 - accuracy: 0.9490
# Epoch 62/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2298 - accuracy: 0.9450
# Epoch 63/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2461 - accuracy: 0.9418
# Epoch 64/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2578 - accuracy: 0.9478
# Epoch 65/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2317 - accuracy: 0.9458
# Epoch 66/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2190 - accuracy: 0.9458
# Epoch 67/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2444 - accuracy: 0.9455
# Epoch 68/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2512 - accuracy: 0.9448
# Epoch 69/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2310 - accuracy: 0.9461
# Epoch 70/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2262 - accuracy: 0.9477
# Epoch 71/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2490 - accuracy: 0.9416
# Epoch 72/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2004 - accuracy: 0.9525
# Epoch 73/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2154 - accuracy: 0.9468
# Epoch 74/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2203 - accuracy: 0.9500
# Epoch 75/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2511 - accuracy: 0.9440
# Epoch 76/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2431 - accuracy: 0.9482
# Epoch 77/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2365 - accuracy: 0.9495
# Epoch 78/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2450 - accuracy: 0.9483
# Epoch 79/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2487 - accuracy: 0.9477
# Epoch 80/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2171 - accuracy: 0.9497
# Epoch 81/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2540 - accuracy: 0.9461
# Epoch 82/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2230 - accuracy: 0.9509
# Epoch 83/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.1950 - accuracy: 0.9552
# Epoch 84/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2059 - accuracy: 0.9557
# Epoch 85/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2234 - accuracy: 0.9500
# Epoch 86/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2154 - accuracy: 0.9554
# Epoch 87/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2264 - accuracy: 0.9529
# Epoch 88/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2169 - accuracy: 0.9554
# Epoch 89/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2335 - accuracy: 0.9514
# Epoch 90/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2050 - accuracy: 0.9527
# Epoch 91/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2368 - accuracy: 0.9519
# Epoch 92/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2314 - accuracy: 0.9532
# Epoch 93/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2183 - accuracy: 0.9514
# Epoch 94/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2355 - accuracy: 0.9505
# Epoch 95/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2091 - accuracy: 0.9549
# Epoch 96/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2365 - accuracy: 0.9529
# Epoch 97/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2461 - accuracy: 0.9500
# Epoch 98/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2056 - accuracy: 0.9578
# Epoch 99/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2287 - accuracy: 0.9510
# Epoch 100/100
# 5942/5942 [==============================] - 6s 1ms/sample - loss: 0.2387 - accuracy: 0.9525

# %%
model.save('chatbot_model.hdf5')

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model("chatbot_model.hdf5")

# %%
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [stemmer.stem(word.lower()) for word in sentence_words]
    return sentence_words

# %%
def bow(sentence, words, show_details=True):
    sentence_words = clean_up_sentence(sentence)
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)

    return(np.array(bag))

# %%
def classify_local(sentence):
    ERROR_THRESHOLD = 0.25
    input_data = pd.DataFrame([bow(sentence, words)], dtype=float, index=['input']).to_numpy()
    results = model.predict([input_data])[0]
    results = [[i, r] for i, r in enumerate(results) if r > ERROR_THRESHOLD]
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append((labels[r[0]], str(r[1])))

    return return_list

# %%
import pandas as pd

# %%
classify_local("Hello")
# Out:
# found in bag: hello
# [('start_conversation', '0.99797636')]

# %%
classify_local("Who are you?")
# Out:
# found in bag: who
# found in bag: you
# [('what_are_you', '0.993885')]

# %%
classify_local("I am to take a surgery")
# Out:
# found in bag: i
# found in bag: am
# found in bag: to
# found in bag: a
# found in bag: surgery
# [('i have spondyloarthritis', '0.4327701')]
